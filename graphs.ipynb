# %% [markdown]
# # Graphs for the paper

# %%
# Imports
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # SSIM Vs. SNR

# %%
SNR = [0,5,10,15,20]
# SSIM values and standard deviations
MoDL = np.array([0.8267, 0.8767, 0.9062, 0.9329, 0.9446])
ViT = np.array([0.9264, 0.9446, 0.9583, 0.9680, 0.9730])
ViT_Fuser = np.array([0.9476, 0.9555, 0.9648, 0.9716, 0.9760])
ViT_Fuser_Hybrid = np.array([0.9487, 0.9517, 0.9608, 0.9683, 0.9726])
ViT_Hybrid = np.array([0.9167, 0.9371, 0.9521, 0.9635, 0.9695])

MoDL_std = np.array([0.0112, 0.0089, 0.0072, 0.0061, 0.0065])
ViT_std = np.array([0.0077, 0.0049, 0.0041, 0.0041, 0.0041])
ViT_Fuser_std = np.array([0.0054, 0.0038, 0.0035, 0.0032, 0.0033])
ViT_Fuser_Hybrid_std = np.array([0.0045, 0.0039, 0.0035, 0.0036, 0.0039])
ViT_Hybrid_std = np.array([0.0079, 0.0057, 0.0049, 0.0043, 0.0048])

# Colors for each plot
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple']

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))
#ax.set_facecolor('lightgray')
#ax.set_facecolor((1, 1, 0.8, 0.3))

# Plot MoDL with consistent color for line and std
ax.errorbar(SNR, MoDL, yerr=MoDL_std, fmt='-^', color=colors[0], label='MoDL - MSE loss', linewidth=2, capsize=4)
ax.fill_between(SNR, MoDL - MoDL_std, MoDL + MoDL_std, color=colors[0], alpha=0.2)
"""
# Plot ViT with consistent color for line and std
ax.errorbar(SNR, ViT, yerr=ViT_std, fmt='-o', color=colors[1], label='ViT - MSE loss', linewidth=2, capsize=4)
ax.fill_between(SNR, ViT - ViT_std, ViT + ViT_std, color=colors[1], alpha=0.2)

# Plot ViT-Fuser with consistent color for line and std
ax.errorbar(SNR, ViT_Fuser, yerr=ViT_Fuser_std, fmt='-s', color=colors[2], label='ViT-Fuser - MSE loss', linewidth=2, capsize=4)
ax.fill_between(SNR, ViT_Fuser - ViT_Fuser_std, ViT_Fuser + ViT_Fuser_std, color=colors[2], alpha=0.2)
"""
# Plot ViT-Hybrid with consistent color for line and std
ax.errorbar(SNR, ViT_Hybrid, yerr=ViT_Hybrid_std, fmt='-d', color=colors[3], label='ViT - Hybrid loss', linewidth=2, capsize=4)
ax.fill_between(SNR, ViT_Hybrid - ViT_Hybrid_std, ViT_Hybrid + ViT_Hybrid_std, color=colors[3], alpha=0.2)

# Plot ViT-Fuser-Hybrid with consistent color for line and std
ax.errorbar(SNR, ViT_Fuser_Hybrid, yerr=ViT_Fuser_Hybrid_std, fmt='-p', color=colors[4], label='ViT-Fuser - Hybrid loss', linewidth=2, capsize=4)
ax.fill_between(SNR, ViT_Fuser_Hybrid - ViT_Fuser_Hybrid_std, ViT_Fuser_Hybrid + ViT_Fuser_Hybrid_std, 
                 color=colors[4], alpha=0.2)


# Customize the plot
ax.set_xlabel('SNR [dB]', fontsize=12)
ax.set_ylabel('SSIM', fontsize=12)
ax.set_title('SSIM Metric as a Function of SNR', fontsize=14)
ax.legend(loc='best', fontsize=10)
ax.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# SSIM vs SNR 2

# %%
SNR = [0,5,10,15,20]
# SSIM values and standard deviations
MoDL = np.array([0.8117, 0.8681, 0.8965,0.9316,0.9424])
ViT_MSE = np.array([0.9248,0.9418,0.9572,0.9667,0.9724])
ViT_SSIM = np.array([0.9252,0.9436,0.9574,0.9666,0.9722])
ViT_Fuser_MSE = np.array([0.9458,0.9537,0.9632,0.9704, 0.9746])
ViT_Fuser_SSIM = np.array([0.9483,0.9535,0.9631,0.9703,0.9747])
ViT_Fuser_Hybrid = np.array([0.9474,0.9503,0.9595,0.9672,0.9721])
ViT_Hybrid = np.array([0.9155,0.9357,0.9516,0.9628,0.9689])

MoDL_std = np.array([0.0114, 0.0087, 0.0088, 0.0058,0.0058])
ViT_MSE_std = np.array([0.0071,0.0052,0.0042,0.0041,0.0040])
ViT_SSIM_std = np.array([0.0074,0.0052,0.0044,0.0042,0.0043])
ViT_Fuser_MSE_std = np.array([0.0051,0.0039,0.0033,0.0030,0.0038])
ViT_Fuser_SSIM_std = np.array([0.0049,0.0039,0.0033,0.0035,0.0037])
ViT_Fuser_Hybrid_std = np.array([0.0047,0.0043,0.0039,0.0037,0.0040])
ViT_Hybrid_std = np.array([0.0080,0.0059,0.0045,0.0048,0.0046])

# Colors for each plot
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple']

# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))
#ax.set_facecolor('lightgray')
#ax.set_facecolor((1, 1, 0.8, 0.3))

# Plot MoDL with consistent color for line and std
ax.errorbar(SNR, MoDL, yerr=MoDL_std, fmt='-^', color=colors[0], label='MoDL - MSE loss', linewidth=2, capsize=4)
ax.fill_between(SNR, MoDL - MoDL_std, MoDL + MoDL_std, color=colors[0], alpha=0.2)

# Plot ViT with consistent color for line and std
ax.errorbar(SNR, ViT_MSE, yerr=ViT_MSE_std, fmt='-o', color=colors[2], label='ViT - MSE loss', linewidth=2, capsize=4)
ax.fill_between(SNR, ViT_MSE - ViT_MSE_std, ViT_MSE + ViT_MSE_std, color=colors[2], alpha=0.2)

# Plot ViT-Fuser with consistent color for line and std
ax.errorbar(SNR, ViT_Fuser_MSE, yerr=ViT_Fuser_MSE_std, fmt='-s', color=colors[4], label='ViT-Fuser - MSE loss', linewidth=2, capsize=4)
ax.fill_between(SNR, ViT_Fuser_MSE - ViT_Fuser_MSE_std, ViT_Fuser_MSE + ViT_Fuser_MSE_std, color=colors[4], alpha=0.2)
"""
# Plot ViT-Hybrid with consistent color for line and std
ax.errorbar(SNR, ViT_Hybrid, yerr=ViT_Hybrid_std, fmt='-d', color=colors[3], label='ViT - Hybrid loss', linewidth=2, capsize=4)
ax.fill_between(SNR, ViT_Hybrid - ViT_Hybrid_std, ViT_Hybrid + ViT_Hybrid_std, color=colors[3], alpha=0.2)

# Plot ViT-Fuser-Hybrid with consistent color for line and std
ax.errorbar(SNR, ViT_Fuser_Hybrid, yerr=ViT_Fuser_Hybrid_std, fmt='-p', color=colors[4], label='ViT-Fuser - Hybrid loss', linewidth=2, capsize=4)
ax.fill_between(SNR, ViT_Fuser_Hybrid - ViT_Fuser_Hybrid_std, ViT_Fuser_Hybrid + ViT_Fuser_Hybrid_std, 
                 color=colors[4], alpha=0.2)
"""

# Customize the plot
ax.set_xlabel('SNR [dB]', fontsize=12)
ax.set_ylabel('SSIM', fontsize=12)
ax.set_title('SSIM Metric as a Function of SNR', fontsize=14)
ax.legend(loc='best', fontsize=10)
ax.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # CMMD vs SNR

# %%
# Data
SNR = np.array([0, 3, 5, 10, 15, 20])  # SNR values (x-axis)

# CMMD metric values for each method
MoDL_MSE = np.array([0.882,0.632,0.489,0.245,0.143, 0.139])

MoDL_Hybrid = np.array([])

ViT_Hybrid = np.array([0.133,0.102,0.094,0.062,0.039,0.022]) 
ViT_MSE = np.array([0.414,0.309, 0.222, 0.128, 0.076])
ViT_SSIM = np.array([0.331,0.244,0.160, 0.097, 0.055])

ViT_Fuser_Hybrid = np.array([0.054,0.046,0.038,0.038,0.026,0.016])

ViT_Fuser_MSE = np.array([0.277,0.276,0.229,0.136, 0.084])
ViT_Fuser_SSIM = np.array([0.250,0.221,0.153,0.092,0.059])


# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))

# Plot MoDL - MSE Loss 
ax.plot(SNR, MoDL_MSE, '-o', color=colors[0], label='MoDL - MSE loss', linewidth=2)

# Plot ViT - Hybrid Loss
ax.plot(SNR, ViT_Hybrid, '-d', color=colors[2], label='ViT - Hybrid loss', linewidth=2, markersize=6)

# Plot ViT-Fuser - Hybrid Loss
ax.plot(SNR, ViT_Fuser_Hybrid, '-^', color=colors[4], label='ViT-Fuser - Hybrid loss', linewidth=2, markersize=6)

# Customize the plot
ax.set_xlabel('SNR [dB]', fontsize=12)
ax.set_ylabel('CMMD Metric Value', fontsize=12)
ax.set_title('CMMD Metric as a Function of SNR', fontsize=14)
ax.legend(loc='upper right', fontsize=10)
ax.grid(True)
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# # FID Vs. SNR

# %%
# Data
SNR = np.array([0, 3, 5, 10, 15, 20])  # SNR values (x-axis)

# FID metric values for each method
MoDL_MSE = np.array([0.7178, 0.1968, 0.0807, 0.0253, 0.0262, 0.0135])
MoDL_Hybrid = np.array([0.942, 0.5102, 0.4286, 0.0958, 0.0401, 0.0162])
ViT_Hybrid = np.array([0.1490, 0.1236, 0.1094, 0.0737, 0.0334, 0.0208])
ViT_Fuser_Hybrid = np.array([0.0459, 0.0500, 0.0389, 0.0322, 0.0229, 0.0114])

# Colors for each method
colors = ['tab:blue', 'tab:red', 'tab:purple', 'tab:green']

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot MoDL - MSE Loss
ax.plot(SNR, MoDL_MSE, '-o', color=colors[0], label='MoDL - MSE loss', linewidth=2, markersize=6)

# Plot MoDL - Hybrid Loss
ax.plot(SNR, MoDL_Hybrid, '--o', color=colors[0], label='MoDL - Hybrid loss', linewidth=2, markersize=6)

# Plot ViT - Hybrid Loss
ax.plot(SNR, ViT_Hybrid, '-d', color=colors[1], label='ViT - Hybrid loss', linewidth=2, markersize=6)

# Plot ViT-Fuser - Hybrid Loss
ax.plot(SNR, ViT_Fuser_Hybrid, '-^', color=colors[2], label='ViT-Fuser - Hybrid loss', linewidth=2, markersize=6)

# Customize the plot
ax.set_xlabel('SNR [dB]', fontsize=12)
ax.set_ylabel('FID Metric Value', fontsize=12)
ax.set_title('FID Metric as a Function of SNR', fontsize=14)
ax.legend(loc='upper right', fontsize=10)
ax.grid(True)
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# # PSNR vs SNR

# %%
SNR = [0,5,10,15,20]
# PSNR values and standard deviations
MoDL = np.array([23.7520,25.5798,26.5289,27.7604,28.35556])
ViT_MSE = np.array([26.8465,27.7691,29.0726,30.3146,31.1448])
ViT_SSIM = np.array([26.2335,27.3705,28.6853,29.8708,30.7087])
ViT_Fuser_MSE = np.array([28.2347,28.673,29.7819,30.8190,31.5429])
ViT_Fuser_SSIM = np.array([27.8465,28.0743,29.1960,30.2950,31.0193])
ViT_Fuser_Hybrid = np.array([28.0479,28.0709,29.0810,30.0421,30.7877])
ViT_Hybrid = np.array([26.0161,27.0159,28.2827,29.5351,30.3228])

MoDL_std = np.array([0.4588,0.4856,0.5854,0.6505,0.6873])
ViT_MSE_std = np.array([0.7248,0.7477,0.7535,0.8231,0.9620])
ViT_SSIM_std = np.array([0.7393,0.7489,0.8021,0.9118,1.064])
ViT_Fuser_MSE_std = np.array([0.7436,0.7018,0.7365,0.7682,0.9529])
ViT_Fuser_SSIM_std = np.array([0.7193,0.7059,0.7544,0.8407,0.9601])
ViT_Fuser_Hybrid_std = np.array([0.7146,0.7003,0.7437,0.7997,0.9460])
ViT_Hybrid_std = np.array([0.7550,0.7597,0.7484,0.8952,1.0041])


# Create the plot
fig, ax = plt.subplots(figsize=(8, 6))
#ax.set_facecolor('lightgray')
#ax.set_facecolor((1, 1, 0.8, 0.3))

# Plot MoDL with consistent color for line and std
ax.errorbar(SNR, MoDL, yerr=MoDL_std, fmt='-^', color=colors[0], label='MoDL - MSE loss', linewidth=2, capsize=4)
ax.fill_between(SNR, MoDL - MoDL_std, MoDL + MoDL_std, color=colors[0], alpha=0.2)
"""
# Plot ViT with consistent color for line and std
ax.errorbar(SNR, ViT_MSE, yerr=ViT_MSE_std, fmt='-o', color=colors[1], label='ViT - MSE loss', linewidth=2, capsize=4)
ax.fill_between(SNR, ViT_MSE - ViT_MSE_std, ViT_MSE + ViT_MSE_std, alpha=0.2)

# Plot ViT-Fuser with consistent color for line and std
ax.errorbar(SNR, ViT_Fuser_MSE, yerr=ViT_Fuser_MSE_std, fmt='-s', color=colors[2], label='ViT-Fuser - MSE loss', linewidth=2, capsize=4)
ax.fill_between(SNR, ViT_Fuser_MSE - ViT_Fuser_MSE_std, ViT_Fuser_MSE + ViT_Fuser_MSE_std, alpha=0.2)
"""
# Plot ViT-Hybrid with consistent color for line and std
ax.errorbar(SNR, ViT_Hybrid, yerr=ViT_Hybrid_std, fmt='-d', color=colors[2], label='ViT - Hybrid loss', linewidth=2, capsize=4)
ax.fill_between(SNR, ViT_Hybrid - ViT_Hybrid_std, ViT_Hybrid + ViT_Hybrid_std, color=colors[2], alpha=0.2)

# Plot ViT-Fuser-Hybrid with consistent color for line and std
ax.errorbar(SNR, ViT_Fuser_Hybrid, yerr=ViT_Fuser_Hybrid_std, fmt='-p', color=colors[4], label='ViT-Fuser - Hybrid loss', linewidth=2, capsize=4)
ax.fill_between(SNR, ViT_Fuser_Hybrid - ViT_Fuser_Hybrid_std, ViT_Fuser_Hybrid + ViT_Fuser_Hybrid_std, 
                 color=colors[4], alpha=0.2)


# Customize the plot
ax.set_xlabel('SNR [dB]', fontsize=12)
ax.set_ylabel('PSNR [dB]', fontsize=12)
ax.set_title('PSNR as a Function of SNR', fontsize=14)
ax.legend(loc='best', fontsize=10)
ax.grid(True)
plt.tight_layout()

# Show the plot
plt.show()
